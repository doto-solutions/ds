# %%
# import polars as pl

# print(
#     pl.read_csv("https://j.mp/iriscsv")
#     .lazy()
#     .filter(pl.col("sepal_length") > 5)
#     .groupby("species", maintain_order=True)
#     .agg(pl.all().sum())
#     .collect()
# )
# Out:
# shape: (3, 5)
# ┌────────────┬──────────────┬─────────────┬──────────────┬─────────────┐
# │ species    ┆ sepal_length ┆ sepal_width ┆ petal_length ┆ petal_width │
# │ ---        ┆ ---          ┆ ---         ┆ ---          ┆ ---         │
# │ str        ┆ f64          ┆ f64         ┆ f64          ┆ f64         │
# ╞════════════╪══════════════╪═════════════╪══════════════╪═════════════╡
# │ setosa     ┆ 116.9        ┆ 81.7        ┆ 33.2         ┆ 6.1         │
# │ versicolor ┆ 281.9        ┆ 131.8       ┆ 202.9        ┆ 63.3        │
# │ virginica  ┆ 324.5        ┆ 146.2       ┆ 273.1        ┆ 99.6        │
# └────────────┴──────────────┴─────────────┴──────────────┴─────────────┘

# %%
import polars as pl
# df=pl.read_parquet_schema('./export.parquet')
df=pl.read_parquet('./export.parquet')
# print(df)
df.head(3)
# Out:
# shape: (3, 19)
# ┌────────────┬────────────┬──────────┬───┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ _airbyte_a ┆ _airbyte_e ┆ id       ┆ n ┆ ... ┆ n_ingredie ┆ updated_by ┆ contributo ┆ _airbyte_a │
# │ b_id       ┆ mitted_at  ┆ ---      ┆ a ┆     ┆ nts        ┆ _id        ┆ r_id       ┆ dditional_ │
# │ ---        ┆ ---        ┆ f64      ┆ m ┆     ┆ ---        ┆ ---        ┆ ---        ┆ properties │
# │ str        ┆ datetime[m ┆          ┆ e ┆     ┆ f64        ┆ f64        ┆ f64        ┆ ---        │
# │            ┆ s, +00:00] ┆          ┆ - ┆     ┆            ┆            ┆            ┆ list[struc │
# │            ┆            ┆          ┆ - ┆     ┆            ┆            ┆            ┆ t[2]]      │
# │            ┆            ┆          ┆ - ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ s ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ t ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ r ┆     ┆            ┆            ┆            ┆            │
# ╞════════════╪════════════╪══════════╪═══╪═════╪════════════╪════════════╪════════════╪════════════╡
# │ 28c06840-8 ┆ 2023-01-04 ┆ 137739.0 ┆ a ┆ ... ┆ 7.0        ┆ 137739.0   ┆ 47892.0    ┆ null       │
# │ 4cf-4644-8 ┆ 14:47:23.8 ┆          ┆ r ┆     ┆            ┆            ┆            ┆            │
# │ 755-f2cbbe ┆ 52 +00:00  ┆          ┆ r ┆     ┆            ┆            ┆            ┆            │
# │ 2c...      ┆            ┆          ┆ i ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ b ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ a ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ b ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ a ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ k ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ e ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ d ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ w ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ i ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ n ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ t ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ e ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ r ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ s ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ q ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ u ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ a ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ s ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ h ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ m ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ e ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ x ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ . ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ . ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ . ┆     ┆            ┆            ┆            ┆            │
# │ af891695-8 ┆ 2023-01-04 ┆ 31490.0  ┆ a ┆ ... ┆ 6.0        ┆ 31490.0    ┆ 26278.0    ┆ null       │
# │ 1ac-4221-8 ┆ 14:47:23.8 ┆          ┆ b ┆     ┆            ┆            ┆            ┆            │
# │ b6e-171333 ┆ 52 +00:00  ┆          ┆ i ┆     ┆            ┆            ┆            ┆            │
# │ a7...      ┆            ┆          ┆ t ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ d ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ i ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ f ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ f ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ e ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ r ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ e ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ n ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ t ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ b ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ r ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ e ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ a ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ k ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ f ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ a ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ s ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ t ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ p ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ i ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ z ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ z ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ a ┆     ┆            ┆            ┆            ┆            │
# │ f939cc12-b ┆ 2023-01-04 ┆ 112140.0 ┆ a ┆ ... ┆ 13.0       ┆ 112140.0   ┆ 196586.0   ┆ null       │
# │ a4b-4d33-8 ┆ 14:47:23.8 ┆          ┆ l ┆     ┆            ┆            ┆            ┆            │
# │ 752-48401a ┆ 52 +00:00  ┆          ┆ l ┆     ┆            ┆            ┆            ┆            │
# │ 78...      ┆            ┆          ┆ i ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ n ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ t ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ h ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ e ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ k ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ i ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ t ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ c ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ h ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ e ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ n ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ c ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ h ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ i ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ l ┆     ┆            ┆            ┆            ┆            │
# │            ┆            ┆          ┆ i ┆     ┆            ┆            ┆            ┆            │
# └────────────┴────────────┴──────────┴───┴─────┴────────────┴────────────┴────────────┴────────────┘

# %%
import polars as pl
df=pl.read_parquet_schema('./export.parquet')
print(df)
# Out:
# {'_airbyte_ab_id': Utf8, '_airbyte_emitted_at': Datetime(tu='ms', tz='+00:00'), 'id': Float64, 'name': Utf8, 'tags': Utf8, 'index': Float64, 'steps': Utf8, 'minutes': Float64, 'n_steps': Float64, 'nutrition': Utf8, 'recipe_id': Float64, 'submitted': Struct([Field('member0': Datetime(tu='us', tz='+00:00')), Field('member1': Utf8)]), 'description': Utf8, 'ingredients': Utf8, 'created_by_id': Float64, 'n_ingredients': Float64, 'updated_by_id': Float64, 'contributor_id': Float64, '_airbyte_additional_properties': List(Struct([Field('key': Utf8), Field('value': Utf8)]))}
